# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df_train = pd.read_csv('./datasets/concatenatedDataset_train.csv')
df_test = pd.read_csv('./datasets/concatenatedDataset_test.csv')

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df_train['2'], df_train['age'])
ax.set_xlabel('Brain comunication')
ax.set_ylabel('Age')
plt.show()

# %%
z = np.abs(stats.zscore(df_train))
print(z)
# Out:
#           age  education    Female      Male         2         3         6  \
# 0    1.389145   0.416480  1.036375  1.036375  0.448409  0.308478  1.744477
# 1    1.344781   0.211893  0.964901  0.964901  0.817392  0.308478  0.532285
# 2    1.300417   0.007307  1.036375  1.036375  0.199795  0.308478  0.301138
# 3    1.300417   0.007307  1.036375  1.036375  0.082957  0.308478  0.709243
# 4    1.300417   0.007307  1.036375  1.036375  0.348074  0.308478  1.303147
# ..        ...        ...       ...       ...       ...       ...       ...
# 107  1.450145   1.030241  1.036375  1.036375  1.800513  0.308478  1.430673
# 108  1.006506   1.030241  0.964901  0.964901  0.141941  0.308478  0.813195
# 109  0.474139   1.030241  0.964901  0.964901  0.860606  0.308478  1.225854
# 110  1.405781   1.234827  1.036375  1.036375  0.222446  0.308478  0.554200
# 111  1.095234   1.030241  0.964901  0.964901  0.900606  0.308478  1.413626
#
# ...
